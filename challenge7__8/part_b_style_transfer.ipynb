# %% [markdown]
# # Challenge 7 — Part B: Neural Style Transfer
# **Group 8 | SVHN (content) → MNIST (style)**
#
# Uses Gatys-style NST with VGG-19 to produce 30 synthetic images per digit class.
# - **Content layer**: `relu4_2` (layer index 21)
# - **Style layers**: `relu1_1, relu2_1, relu3_1, relu4_1, relu5_1`
# - **Loss**: `α=1.0, β=1e4`, 300 L-BFGS steps

# %%
import sys, os
sys.path.insert(0, '..')
os.chdir('..')

from style_transfer import generate_synthetic_images

generate_synthetic_images(
    out_dir='./data/synthetic_target',
    figures_dir='./figures',
    data_root='./data',
    per_class=30,
)

# %%
from IPython.display import Image, display
display(Image('figures/nst_gallery.png'))
